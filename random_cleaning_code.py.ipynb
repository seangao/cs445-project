# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression

# %%
games_train = pd.read_csv('games_train.csv', header=None)

games_test = pd.read_csv('games_test.csv', header=None)

games_2011 = pd.read_csv('csv/team_stats/off/2011.csv')
games_2012 = pd.read_csv('csv/team_stats/off/2012.csv')
games_2013 = pd.read_csv('csv/team_stats/off/2013.csv')
games_2014 = pd.read_csv('csv/team_stats/off/2014.csv')
games_2015 = pd.read_csv('csv/team_stats/off/2015.csv')
games_2016 = pd.read_csv('csv/team_stats/off/2016.csv')

# %%
games_2016['Team'] = [team[:-1] if team[-1] == '*' else team for team in games_2016['Team']]
games_2016.to_csv('csv/team_stats/off/2016.csv', index=None)

games_2015['Team'] = [team[:-1] if team[-1] == '*' else team for team in games_2015['Team']]
games_2015.to_csv('csv/team_stats/off/2015.csv', index=None)

games_2014['Team'] = [team[:-1] if team[-1] == '*' else team for team in games_2014['Team']]
games_2014.to_csv('csv/team_stats/off/2014.csv', index=None)

games_2013['Team'] = [team[:-1] if team[-1] == '*' else team for team in games_2013['Team']]
games_2013.to_csv('csv/team_stats/off/2013.csv', index=None)

games_2012['Team'] = [team[:-1] if team[-1] == '*' else team for team in games_2012['Team']]
games_2012.to_csv('csv/team_stats/off/2012.csv', index=None)

games_2011['Team'] = [team[:-1] if team[-1] == '*' else team for team in games_2011['Team']]
games_2011.to_csv('csv/team_stats/off/2011.csv', index=None)

# %%
team_names = [team[:-1] if team[-1] == '*' else team for team in games_2016['Team']]

# %%
old_team_names = games_2011['Team'] = [team[:-1] if team[-1] == '*' else team for team in games_2011['Team']]

# %%
intersect = set(team_names).intersection(set(old_team_names))

# %%
team_old_list = [team_old for team_old, team_new in zip(old_team_names, team_names) if team_old not in intersect]
team_new_list = [team_new for team_old, team_new in zip(old_team_names, team_names) if team_new not in intersect]

# %%
team_old_list
# Out:
# ['New Orleans Hornets', 'New Jersey Nets', 'Charlotte Bobcats']

# %%
team_new_list
# Out:
# ['Charlotte Hornets', 'New Orleans Pelicans', 'Brooklyn Nets']

# %%
team_map = {team_old_list[0]:team_new_list[1],team_old_list[1]:team_new_list[2],team_old_list[2]:team_new_list[0]}

# %%
team_map
# Out:
# {'Charlotte Bobcats': 'Charlotte Hornets',
#  'New Jersey Nets': 'Brooklyn Nets',
#  'New Orleans Hornets': 'New Orleans Pelicans'}

# %%
games_2015['Team'] = [team_map[team] if team in team_map else team for team in games_2015['Team']]
games_2015.to_csv('csv/team_stats/off/2015.csv', index=None)

games_2014['Team'] = [team_map[team] if team in team_map else team for team in games_2014['Team']]
games_2014.to_csv('csv/team_stats/off/2014.csv', index=None)

games_2013['Team'] = [team_map[team] if team in team_map else team for team in games_2013['Team']]
games_2013.to_csv('csv/team_stats/off/2013.csv', index=None)

games_2012['Team'] = [team_map[team] if team in team_map else team for team in games_2012['Team']]
games_2012.to_csv('csv/team_stats/off/2012.csv', index=None)

games_2011['Team'] = [team_map[team] if team in team_map else team for team in games_2011['Team']]
games_2011.to_csv('csv/team_stats/off/2011.csv', index=None)

# %%
games_2011
# Out:
#     Rk                    Team   G     MP    FG   FGA    FG%   3P   3PA  \
# 0    1          Denver Nuggets  82  19705  3145  6613  0.476  662  1704
# 1    2         New York Knicks  82  19780  3140  6867  0.457  765  2081
# 2    3         Houston Rockets  82  19880  3170  6975  0.454  677  1843
# 3    4            Phoenix Suns  82  20005  3219  6844  0.470  701  1857
# 4    5   Oklahoma City Thunder  82  20005  3066  6609  0.464  487  1403
# 5    6       San Antonio Spurs  82  19780  3148  6628  0.475  685  1727
# 6    7   Golden State Warriors  82  19830  3251  7047  0.461  685  1749
# 7    8              Miami Heat  82  19780  3031  6301  0.481  547  1479
# 8    9      Los Angeles Lakers  82  19830  3128  6757  0.463  524  1487
# 9   10  Minnesota Timberwolves  82  19780  3090  7014  0.441  589  1565
# 10  11        Dallas Mavericks  82  19705  3069  6463  0.475  645  1768
# 11  12       Memphis Grizzlies  82  19880  3200  6801  0.471  309   926
# ...

# %%
model = LogisticRegression()
model.fit(X, y)
