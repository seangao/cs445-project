# %%
import numpy as np
import pandas as pd

train = pd.read_csv('games_train.csv', delimiter=',', header=None)
team_stats = {}
for year in range(2011, 2017):
    team_stats[year] = pd.read_csv('csv/team_stats/off/'+str(year)+'.csv')

team_stat_names = list(team_stats[2011].columns.values)[4:]
opp_stat_names = ['Opp'+name for name in team_stat_names]
column_names = team_stat_names + opp_stat_names
column_names.append('YrsSince2011')

train_stats = pd.DataFrame(index=range(train.shape[0]*2), columns = column_names)
for ind,game in train.iterrows():
    year = game[4]
    left_team = game[0]
    right_team = game[2]
    for ind,team in team_stats[year].iterrows():
        print(team[['Team']])
        if team[['Team']]==left_team:
            left_team_stats=team[team_stat_names]
        if team[['Team']]==right_team:
            right_team_stats=team[team_stat_names]
    print(left_team, left_team_stats)
    #train_stats.loc[ind]['YrsSince2011'] = year-2011
print(train_stats['YrsSince2011'])
#    print(game[4])
#print(train)
#print(team_stats)
# Out:
# Team    Denver Nuggets
# Name: 0, dtype: object
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-2fca3ae3eacf> in <module>()
#      19     for ind,team in team_stats[year].iterrows():
#      20         print(team[['Team']])
# ---> 21         if team[0, ['Team']]==left_team:
#      22             left_team_stats=team[team_stat_names]
#      23         if team[0, ['Team']]==right_team:
#
# /Users/adrianlin/anaconda/lib/python3.5/site-packages/pandas/core/series.py in __getitem__(self, key)
#     640             key = check_bool_indexer(self.index, key)
#     641
# --> 642         return self._get_with(key)
#     643
#     644     def _get_with(self, key):
#
# /Users/adrianlin/anaconda/lib/python3.5/site-packages/pandas/core/series.py in _get_with(self, key)
#     653             if isinstance(key, tuple):
#     654                 try:
# --> 655                     return self._get_values_tuple(key)
#     656                 except:
#     657                     if len(key) == 1:
#
# /Users/adrianlin/anaconda/lib/python3.5/site-packages/pandas/core/series.py in _get_values_tuple(self, key)
#     698
#     699         if not isinstance(self.index, MultiIndex):
# --> 700             raise ValueError('Can only tuple-index with a MultiIndex')
#     701
#     702         # If key is contained, would have returned by now
#
# ValueError: Can only tuple-index with a MultiIndex

# %%
team_stats[2011][['Team']]
# Out:
#                       Team
# 0           Denver Nuggets
# 1          New York Knicks
# 2          Houston Rockets
# 3             Phoenix Suns
# 4    Oklahoma City Thunder
# 5        San Antonio Spurs
# 6    Golden State Warriors
# 7               Miami Heat
# 8       Los Angeles Lakers
# 9   Minnesota Timberwolves
# 10        Dallas Mavericks
# 11       Memphis Grizzlies
# 12          Indiana Pacers
# 13               Utah Jazz
# 14        Sacramento Kings
# 15           Orlando Magic
# 16         Toronto Raptors
# 17      Philadelphia 76ers
# 18    Los Angeles Clippers
# 19           Chicago Bulls
# 20      Washington Wizards
# 21         Detroit Pistons
# 22          Boston Celtics
# 23  Portland Trail Blazers
# 24     Cleveland Cavaliers
# 25           Atlanta Hawks
# 26     New Orleans Hornets
# 27         New Jersey Nets
# 28       Charlotte Bobcats
# 29         Milwaukee Bucks
